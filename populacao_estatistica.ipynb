# %% [markdown]
# <a href="https://colab.research.google.com/github/dxdiego5/data-science-growdev-matematica-statistica/blob/main/populacao_estatistica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ESTATISTICA POPULACIONAL (POPULACAO)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# %%
iris = load_iris()
x = iris.data[:, 0:5]
feature_names = ['sepal length (cm)' , 'sepal width (cm)', 'petal length (cm)','petal with (cm)']
x = pd.DataFrame(x,columns=feature_names)
x
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal with (cm)
# 0                  5.1               3.5                1.4              0.2
# 1                  4.9               3.0                1.4              0.2
# 2                  4.7               3.2                1.3              0.2
# 3                  4.6               3.1                1.5              0.2
# 4                  5.0               3.6                1.4              0.2
# ..                 ...               ...                ...              ...
# 145                6.7               3.0                5.2              2.3
# 146                6.3               2.5                5.0              1.9
# 147                6.5               3.0                5.2              2.0
# 148                6.2               3.4                5.4              2.3
# 149                5.9               3.0                5.1              1.8
#
# [150 rows x 4 columns]

# %%
x.hist()
plt.show()

# %%
dataset=pd.read_csv('Iris.csv',sep=',')
dataset =pd.DataFrame(dataset)
dataset
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...
